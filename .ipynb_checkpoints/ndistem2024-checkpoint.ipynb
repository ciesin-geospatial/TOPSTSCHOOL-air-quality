# %%
import arcgis
from arcgis.gis import GIS
from arcgis.raster import *
# from arcgis.layers import Service

# %%
# Connect to your ArcGIS Enteprise or AGOL
portal_url = 'https://gis.earthdata.nasa.gov/portal'
gis = GIS(portal_url) #anonymous user

# %%
map_view = gis.map("Arizona")  # Adjust the location as needed

# Add the raster layer directly to the map
# map_view.add_layer(md_raster)  # Assuming md_raster is your Raster object
map_view
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-5524774a-526b-4f48-a43e-b5ce0883071f"><img src=""></img></div>
# <div class="map-html-embed-preview-5524774a-526b-4f48-a43e-b5ce0883071f"></div>

# %%
#query Portal Content
query="TEMPO"
max_items=3
portal_content = gis.content.advanced_search(query=query, max_items=max_items)
for item in portal_content['results']:
        display (item)
# Out:
# <Item title:"(Under Development) Tropospheric Emissions: Monitoring of Pollution (TEMPO) Version 03 Level 3 Gridded Formaldehyde (HCHO) Vertical Column (BETA)" type:Imagery Layer owner:ASDC_Publisher>
# <Item title:"3D Viewer" type:Web Mapping Application owner:esri_pt>
# <Item title:"Análise CCDC" type:Raster function template owner:esri_po>

# %%
item = portal_content['results'][0]
item
# Out:
# <Item title:"(Under Development) Tropospheric Emissions: Monitoring of Pollution (TEMPO) Version 03 Level 3 Gridded Formaldehyde (HCHO) Vertical Column (BETA)" type:Imagery Layer owner:ASDC_Publisher>

# %%
item_layers = item.layers
for layer in item_layers:
    print(layer)
# Out:
# <ImageryLayer url:"https://gis.earthdata.nasa.gov/UAT/rest/services/TEMPO/TEMPO_HCHO_L3_V03/ImageServer">

# %%
layer= item_layers[0]
print(layer.url)
layer
# Out:
# https://gis.earthdata.nasa.gov/UAT/rest/services/TEMPO/TEMPO_HCHO_L3_V03/ImageServer
# <ImageryLayer url:"https://gis.earthdata.nasa.gov/UAT/rest/services/TEMPO/TEMPO_HCHO_L3_V03/ImageServer">

# %%
md_raster = Raster(layer.url, is_multidimensional=True, engine=None, gis=gis)
md_raster.variable_names
# Out:
# ['HCHO']

# %%
var_name = md_raster.variable_names[0]
var_name
# Out:
# 'HCHO'

# %%
time_variable_values = md_raster.multidimensional_info['multidimensionalInfo']['variables'][0]['dimensions'][0]['values']

# %%
len(time_variable_values)
# Out:
# 6105

# %%
single_time_var = time_variable_values[333]
single_time_var
# Out:
# '2023-08-28T23:38:41+00:00'

# %%
# Apply the multidimensional filter to subset the raster for the specified time
filtered_raster = multidimensional_filter(
    raster=md_raster,
    variables=[var_name],
    dimension={"StdTime": single_time_var}
)

# %%
# Create a MapView centered on your area of interest
map_view = gis.map("Arizona")  # Adjust the location as needed

# Add the raster layer directly to the map
# map_view.add_layer(filtered_raster)  # Assuming md_raster is your Raster object
map_view
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-1893f90e-7405-47c0-bfd4-ed3b72f48cf9"><img src=""></img></div>
# <div class="map-html-embed-preview-1893f90e-7405-47c0-bfd4-ed3b72f48cf9"></div>

# %%
# Display the filtered raster on a map
map_view = gis.map("Your Location")  # Replace with a relevant location or leave blank
map_view.add_layer(filtered_raster)
map_view
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_40580\1346985195.py in <cell line: 3>()
#       1 # Display the filtered raster on a map
#       2 map_view = gis.map("Your Location")  # Replace with a relevant location or leave blank
# ----> 3 map_view.add_layer(filtered_raster)
#       4 map_view
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
#Print Image Service Multidimensional Info
print(md_raster.multidimensional_info)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _hydrate(self)
#   16930             try:
# > 16931                 self._refresh()
#   16932
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _refresh(self)
#   16904                 else:
# > 16905                     raise e
#   16906
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _refresh(self)
#   16887                 if is_raster:
# > 16888                     dictdata = self._con.post(
#   16889                         self.url,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1371
# -> 1372         if url.find("://") == -1:
#    1373             url = self._baseurl + url
#
# AttributeError: 'ImageryLayer' object has no attribute 'find'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_40580\4092932211.py in <cell line: 2>()
#       1 #Print Image Service Multidimensional Info
# ----> 2 print(md_raster.multidimensional_info)
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\raster\_layer.py in multidimensional_info(self)
#    7689         including variable names, descriptions and units, and dimension names, units, intervals, units, and ranges.
#    7690         """
# -> 7691         return self._engine_obj.multidimensional_info
#    7692
#    7693     @property
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\raster\_layer.py in multidimensional_info(self)
#    9697     @property
#    9698     def multidimensional_info(self):
# -> 9699         mdinfo = super().multidimensional_info
#    9700         if mdinfo is not None:
#    9701             for index, ele in enumerate(mdinfo["multidimensionalInfo"]["variables"]):
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\raster\_layer.py in multidimensional_info(self)
#    1123         """
#    1124         if (
# -> 1125             "hasMultidimensions" in self.properties
#    1126             and self.properties["hasMultidimensions"] == True
#    1127         ) or self._datastore_raster:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in properties(self)
#   16915             return self._lazy_properties
#   16916         else:
# > 16917             self._hydrate()
#   16918             return self._lazy_properties
#   16919
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _hydrate(self)
#   16952                     # try as a public server
#   16953                     self._lazy_token = None
# > 16954                     self._refresh()
#   16955
#   16956                 except HTTPError as httperror:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _refresh(self)
#   16903                     dictdata = self._con.get(self.url, params)
#   16904                 else:
# > 16905                     raise e
#   16906
#   16907         self._lazy_properties = _mixins.PropertyMap(dictdata)
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in _refresh(self)
#   16886             try:
#   16887                 if is_raster:
# > 16888                     dictdata = self._con.post(
#   16889                         self.url,
#   16890                         params,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1370         try_json = kwargs.pop("try_json", True)
#    1371
# -> 1372         if url.find("://") == -1:
#    1373             url = self._baseurl + url
#    1374         if kwargs.pop("ssl", False) or self._all_ssl:
#
# AttributeError: 'ImageryLayer' object has no attribute 'find'

# %%
item_content = gis.content.get(item.id)
item_content
# Out:
# <Item title:"Global Annual PM2.5 Grids from MODIS, MISR and SeaWiFS Aerosol Optical Depth (AOD), 1998-2019, V4.GL.03   " type:Imagery Layer owner:NASA_Earthdata>

# %%
m = gis.map()
m.add_layer(item_content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\1769480042.py in <cell line: 2>()
#       1 m = gis.map()
# ----> 2 m.add_layer(item_content)
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
for layer in item.layers:
    print(layer.properties.name)
# Out:
# sdei/sdei-global-annual-gwr-pm2-5-modis-misr-seawifs-aod-v4-gl-03

# %%
m = gis.map('Arizona', 3)
m
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-02a088ef-a73b-4477-9c6d-73ad265b7e27"><img src=""></img></div>
# <div class="map-html-embed-preview-02a088ef-a73b-4477-9c6d-73ad265b7e27"></div>

# %%
m.add_layer(gpw_bdc_layer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\48994902.py in <cell line: 1>()
# ----> 1 m.add_layer(gpw_bdc_layer)
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
pm25_layer = item.layers[0]
pm25_layer
# Out:
# <ImageryLayer url:"https://gis.earthdata.nasa.gov/image/rest/services/sdei/sdei-global-annual-gwr-pm2-5-modis-misr-seawifs-aod-v4-gl-03/ImageServer">

# %%
for fn in gpw_bdc_layer.properties.rasterFunctionInfos:
    print(fn['name'])
# Out:
# None

# %%
gpw_bdc_layer.properties.rasterFunctionInfos[0]['name']
# Out:
# 'None'

# %%
from arcgis.raster.functions import apply
try:
    processed_layer = apply(gpw_bdc_layer, "None")  # Use a valid function name here

    # Add the processed layer to the map
    map_view = gis.map('Arizona')
    map_view.add_layer(processed_layer)
    map_view

except Exception as e:
    print("An error occurred:", e)
# Out:
# An error occurred: 'NoneType' object has no attribute 'DataFrame'

# %%
gis = GIS("home")
map_view = gis.map('Arizona')
map_view.add_layer(gpw_bdc_layer)
map_view
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\1656100368.py in <cell line: 3>()
#       1 gis = GIS("home")
#       2 map_view = gis.map('Arizona')
# ----> 3 map_view.add_layer(gpw_bdc_layer)
#       4 map_view
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
#Assuming `gpw_bdc_layer` is your raster layer item
# Apply a raster function to the layer
processed_layer = apply(gpw_bdc_layer, gpw_bdc_layer.properties.rasterFunctionInfos[0]['name'])

# Create a MapView and add the processed layer directly
map_view = gis.map('Arizona')
map_view.add_layer(processed_layer)
map_view
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\2955251696.py in <cell line: 7>()
#       5 # Create a MapView and add the processed layer directly
#       6 map_view = gis.map('Arizona')
# ----> 7 map_view.add_layer(processed_layer)
#       8 map_view
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
show(gpw_bdc_layer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\3786629873.py in <cell line: 1>()
# ----> 1 show(gpw_bdc_layer)
#
# NameError: name 'show' is not defined

# %%
item_content
# Out:
# <Item title:"GPW  Version 4 Basic Demographic Characteristics (Adjusted to UN Country Totals)" type:Imagery Layer owner:NASA_Earthdata>

# %%
item_content = gis.content.get(item_id)  # Retrieve the item by ID

# Create a MapView and add the item as a layer
map_view = gis.map()
map_view.add_layer(item_content)
map_view
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\1056518707.py in <cell line: 5>()
#       3 # Create a MapView and add the item as a layer
#       4 map_view = gis.map()
# ----> 5 map_view.add_layer(item_content)
#       6 map_view
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'

# %%
map = gis.map()
map.add_layer(item)
map
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\9\ipykernel_23560\3370249586.py in <cell line: 2>()
#       1 map = gis.map()
# ----> 2 map.add_layer(item)
#       3 map
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\widgets\_mapview\_mapview.py in add_layer(self, item, options)
#    1498                 options["renderer"] = renderer_dict
#    1499         elif (
# -> 1500             isinstance(item, pd.DataFrame)
#    1501             and "renderer" not in options
#    1502             and _is_geoenabled(item)
#
# AttributeError: 'NoneType' object has no attribute 'DataFrame'
