# %% [markdown]
# ## QuantAQ acquisition: South Bronx devices, November 7–10, 2024
#
# This notebook focuses **only on data acquisition** from QuantAQ.
#
# ### What is QuantAQ?
#
# QuantAQ devices are **air-quality monitors** that report time-series measurements (often including particulate matter and supporting environmental variables, depending on the device model and configuration). In this lesson, QuantAQ provides a **dense, neighborhood-scale monitoring network** in the South Bronx.
#
# In the South Bronx, this dense QuantAQ network exists thanks to the environmental justice work of **South Bronx Unite** and research partners including **Dr. Markus Hilpert** and collaborators. The sample QuantAQ data used in this lesson was provided through this collaboration.
#
# QuantAQ data are especially useful for:
#
# - Seeing **neighborhood-scale patterns** when many devices are deployed in one area,
# - Comparing **time patterns** across different data sources (data cleaning and alignment happen later),
# - Supporting short “event window” analysis with **high-frequency measurements**.
#
# As with any sensor dataset, these measurements should be treated as **raw observations** that may require quality checks before drawing strong conclusions. Those steps are discussed further in this lesson’s `m201-air-quality-measures-integrated` notebook.
#
# ### What this notebook does
#
# - Authenticates with the QuantAQ API,
# - Lists devices available to the provided API key (for this lesson, access is within the South Bronx Unite / Hilpert network),
# - Downloads measurements for each device for the event window (Nov 7–10, 2024),
# - Saves outputs to `data/raw/quantaq/` for later integration.
#
# No plotting, resampling, or integrated analysis is performed here. Those steps will happen later in
# the `m201-air-quality-measures-integrated` notebook.

# %% [markdown]
# ## QuantAQ data access
#
# QuantAQ data are accessed through an API using an API key.
#
# - Create a QuantAQ account and generate an API key from the QuantAQ web application.
# - This notebook will prompt you for the key using `getpass` so it is not printed to the screen.
# - Note: access to the **South Bronx Unite / Hilpert** South Bronx network is not public; this lesson assumes your credentials have already been granted access.

# %% [markdown]
# ## Install the QuantAQ Python client
#
# If the `quantaq` package is not installed in your environment, install it from the official repository.

# %%
try:
    import quantaq
    print("quantaq is already installed")
except ImportError:
    # !pip install git+https://github.com/quant-aq/py-quantaq.git
# Out:
# quantaq is already installed

# %% [markdown]
# ## Set up the API client
#
# Enter your QuantAQ API key when prompted. The key will be used only for this notebook session.

# %%
# import the library
import quantaq
import os, getpass

# Prompt for the API key (not echoed) and set it for this notebook session
if "QUANTAQ_APIKEY" not in os.environ or not os.environ["QUANTAQ_APIKEY"]:
    os.environ["QUANTAQ_APIKEY"] = getpass.getpass("Enter your QuantAQ API key: ")

# Initialize the QuantAQ client
client = quantaq.QuantAQAPIClient(api_key=os.environ["QUANTAQ_APIKEY"])

# %% [markdown]
# ## Verify access
#
# These quick checks confirm that your API key works and that you can see organizations and devices associated with your account.

# %%
# verify account information
whoami = client.whoami()
print (whoami)
# You can retrieve a list of all the organizations visible to you:
organizations = client.organizations.list()
print (organizations)
# You can retrieve a list of all the devices visible to you:
devices = client.devices.list()
for device in  devices:
    print(device["description"])
# Out:
# {'confirmed': True, 'email': 'topstschool@ciesin.columbia.edu', 'first_name': 'TOPS', 'id': 2704, 'is_administrator': False, 'last_name': 'SCHOOL', 'last_seen': '2025-08-19T17:49:01.880539', 'member_since': '2025-01-31T14:38:35.980542', 'role': 1, 'username': 'topstschool'}
# [{'created_on': '2023-10-18T20:43:11.197345+00:00', 'description': 'South Bronx Unite brings together neighborhood residents, community organizations, academic institutions, and allies to improve and protect the social, environmental, and economic future of Mott Haven and Port Morris.', 'devices': ['MOD-PM-01325', 'MOD-PM-01163', 'MOD-PM-01317', 'MOD-PM-01158', 'MOD-PM-01153', 'MOD-PM-01147', 'MOD-PM-01323', 'MOD-PM-01328', 'MOD-PM-01463', 'MOD-PM-01334', 'MOD-PM-01330', 'MOD-00478', 'MOD-PM-01146', 'MOD-PM-01152', 'MOD-PM-01160', 'MOD-PM-01145', 'MOD-PM-01157', 'MOD-00693', 'MOD-00780', 'MOD-PM-01154', 'MOD-PM-01324', 'MOD-00695', 'MOD-PM-01161', 'MOD-00697', 'MOD-00480', 'MOD-PM-01320', 'MOD-PM-01144', 'MOD-PM-01149', 'MOD-PM-01159', 'MOD-PM-01321', 'MOD-PM-01460', 'MOD-PM-01466', 'MOD-PM-01316', 'MOD-PM-01322', 'MOD-PM-01333', 'MOD-PM-01326', 'MOD-PM-01319', 'MOD-PM-01318', 'MOD-00479', 'MOD-PM-01148', 'MOD-PM-01464', 'MOD-PM-01468', 'MOD-PM-01462', 'MOD-00482', 'MOD-PM-01331', 'MOD-00779', 'MOD-00696', 'MOD-00778', 'MOD-PM-01150', 'MOD-00781', 'MOD-PM-01332', 'MOD-PM-01156', 'MOD-PM-01465', 'MOD-PM-01467', 'MOD-PM-01315', 'MOD-PM-01162', 'MOD-PM-01155', 'MOD-PM-01327', 'MOD-PM-01151', 'MOD-00481', 'MOD-00782', 'MOD-00694', 'MOD-PM-01459', 'MOD-PM-01461', 'MOD-PM-01329'], 'id': 1295, 'members': [{'role': 'member', 'user': 'topstschool'}], 'name': 'South Bronx Unite', 'networks': [99], 'sandbox': False, 'url': 'https://api.quant-aq.com/v1/orgs/1295'}, {'created_on': '2025-01-31T14:38:35.986928+00:00', 'description': 'Only you can see devices here', 'devices': [], 'id': 2574, 'members': [{'role': 'admin', 'user': 'topstschool'}], 'name': 'topstschool Sandbox 5194', 'networks': [], 'sandbox': True, 'url': 'https://api.quant-aq.com/v1/orgs/2574'}]
# MOD-PM-01144 - La Finca del Sur (110 E 138th St)
# MOD-PM-01145 - St Ann's Episcopal Church
# MOD-PM-01146 - The Family School
# MOD-PM-01147 - 335 E 140th St
# MOD-PM-01148 - Ethical Culture Fieldston School
# MOD-PM-01149, Association for Energy Affordability
# MOD-PM-01150 - Brook Park
# MOD-00478, SBU Office
# MOD-00479 - Bruckner Garden
# MOD-00480 - Harlem River Yards Waste Transfer Station
# MOD-00481 - South Bronx Unite Office (Outside)
# MOD-00482 - Governors Island (Liberty Vista)
# MOD-PM-01151 - 408 E 136th St
# MOD-PM-01152 - MSHS 223 (423 Willis Ave)
# MOD-PM-01153 - Latino Pastoral Action Center
# MOD-PM-01154 - El Coqui Garden (414 E 163rd St)
# MOD-PM-01155 Revel Site (799 E 140th St)
# MOD-PM-01156 Rainbow Garden
# MOD-PM-01157 - P.S 126 Dr Marjorie H. Dunbar School
# MOD-PM-01158 - MSHS 223 (368 E 144th St)
# MOD-PM-01159 - 33 Tinton Ave
# MOD-PM-01160 - MS 302: Ground Level
# MOD-PM-01161 X285 The Highbridge Green School
# MOD-PM-01162 870 Southern Boulevard (SEBCO)
# MOD-PM-01163 - NYCSBUS Zerega School Bus Depot (1101 Zerega Ave)
# MOD-PM-01315 - Bronx Collegiate Academy
# SBU Test Monitor 4 - PM
# MOD-PM-01317 - Maria Sola Garden
# MOD-PM-01318, 1212 Seneca Ave (SEBCO)
# SBU
# MOD-PM-01320 P.S.170
# MOD-PM-01321 817 Faile St (SEBCO)
# MOD-PM-01322, 852 E 165th St (SEBCO)
# MOD-PM-01323 X114 Lewis Llorens Torres Academy
# MOD-PM-01324 - 567 Southern Boulevard (SEBCO)
# MOD-PM-01325, 852 E 163rd St (SEBCO)
# MOD-PM-01326 - 580 Courtlandt Ave (SEBCO)
# MOD-PM-01327 - Test Monitor 9 - PM
# MOD-PM-01328 - 665 Casanova St (SEBCO)
# MOD-PM-01329 - Test Monitor 10 - PM
# MOD-PM-01330- P.S. 070 Max Schoenfeld School
# MOD-PM-01331 - 575 E 161st St (SEBCO)
# MOD-PM-01333 - SEBCO 390 Jackson Ave
# MOD-PM-01334 - 479 Courtlandt Ave (SEBCO)
# MOD-PM-01332 994 Intervale Ave (SEBCO)
# MOD-00693 - Cross Bronx Expressway
# MOD-00694
# MOD-00695 - 1150 Garrison Ave (SEBCO)
# MOD-00696 Randall's Island/Sunken Meadow Restroom
# MOD-00697 - Hostos Community College
# MOD-00778 Residential Apt. - 700 E 134th St
# MOD-00779 - MS 302 (DEC Monitor) (Roof)
# MOD-00780 MS 004 (Crotona Park West) GAS
# MOD-00781 - SBU big conf. rm. 127 Lincoln Ave.
# MOD-00782 X320 Samara Community School
# MOD-PM-01459
# MOD-PM-01460, P.S.11 The Highbridge School
# MOD-PM-01461
# MOD-PM-01462 - The Shakespear School (P.S. 199)
# MOD-PM-01463 - Bronx Leadership Academy HS (X876)
# MOD-PM-01464 - (X460) Bronx School for Law, Government and Justice
# MOD-PM-01465 P.S. X088 Silverstein Little Sparrow School
# MOD-PM-01466 - School X147 School of leadership development
# SBU
# SBU

# %% [markdown]
# ## Optional: preview a device and a few recent records
#
# This is a small “smoke test” that the API is returning data. It pulls a handful of recent records from a single device.

# %%
# You can limit the return to just the most recent data points from a single device:
recent = client.data.list(sn='MOD-00480', sort="timestamp,asc", limit=10)
for r in recent:
    print(r)
# Out:
# {'co': None, 'geo': {'lat': 40.806, 'lon': -73.93}, 'met': {'rh': 90.0, 'temp': 6.1, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 4.18, 'pm10': 167.16, 'pm25': 6.95, 'raw_data_id': 83357948, 'rh': 90.0, 'sn': 'MOD-00480', 'temp': 6.1, 'timestamp': '2000-01-01T00:01:01', 'timestamp_local': '1999-12-31T19:01:01', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/83357866'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 39.2, 'temp': 25.9, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.12, 'pm10': 4.33, 'pm25': 2.46, 'raw_data_id': 62314430, 'rh': 39.2, 'sn': 'MOD-00480', 'temp': 25.9, 'timestamp': '2023-09-15T16:45:28', 'timestamp_local': '2023-09-15T12:45:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62314344'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 39.0, 'temp': 25.9, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.17, 'pm10': 45.38, 'pm25': 2.66, 'raw_data_id': 62314427, 'rh': 39.0, 'sn': 'MOD-00480', 'temp': 25.9, 'timestamp': '2023-09-15T16:46:28', 'timestamp_local': '2023-09-15T12:46:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62314345'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.6, 'temp': 25.9, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.43, 'pm10': 6.38, 'pm25': 2.87, 'raw_data_id': 62314426, 'rh': 38.6, 'sn': 'MOD-00480', 'temp': 25.9, 'timestamp': '2023-09-15T16:47:28', 'timestamp_local': '2023-09-15T12:47:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62314348'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.7, 'temp': 26.0, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.56, 'pm10': 10.06, 'pm25': 2.98, 'raw_data_id': 62314428, 'rh': 38.7, 'sn': 'MOD-00480', 'temp': 26.0, 'timestamp': '2023-09-15T16:48:28', 'timestamp_local': '2023-09-15T12:48:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62314347'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.9, 'temp': 26.0, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.07, 'pm10': 27.31, 'pm25': 2.33, 'raw_data_id': 62314429, 'rh': 38.9, 'sn': 'MOD-00480', 'temp': 26.0, 'timestamp': '2023-09-15T16:49:28', 'timestamp_local': '2023-09-15T12:49:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62314346'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.8, 'temp': 26.1, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.19, 'pm10': 35.09, 'pm25': 2.55, 'raw_data_id': 62315186, 'rh': 38.8, 'sn': 'MOD-00480', 'temp': 26.1, 'timestamp': '2023-09-15T16:50:28', 'timestamp_local': '2023-09-15T12:50:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62315104'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.6, 'temp': 26.1, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.78, 'pm10': 26.26, 'pm25': 3.24, 'raw_data_id': 62315184, 'rh': 38.6, 'sn': 'MOD-00480', 'temp': 26.1, 'timestamp': '2023-09-15T16:51:28', 'timestamp_local': '2023-09-15T12:51:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62315102'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 38.1, 'temp': 26.2, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 2.61, 'pm10': 30.08, 'pm25': 3.12, 'raw_data_id': 62315185, 'rh': 38.1, 'sn': 'MOD-00480', 'temp': 26.2, 'timestamp': '2023-09-15T16:52:28', 'timestamp_local': '2023-09-15T12:52:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62315103'}
# {'co': None, 'geo': {'lat': None, 'lon': None}, 'met': {'rh': 37.8, 'temp': 26.2, 'wd': 0.0, 'ws': None, 'ws_scalar': 0.0}, 'model': {'gas': {'co': None, 'no': None, 'no2': None, 'o3': None}, 'pm': {'pm1': 11669, 'pm10': 11671, 'pm25': 11670}}, 'no': None, 'no2': None, 'o3': None, 'pm1': 3.41, 'pm10': 27.78, 'pm25': 3.94, 'raw_data_id': 62315183, 'rh': 37.8, 'sn': 'MOD-00480', 'temp': 26.2, 'timestamp': '2023-09-15T16:53:28', 'timestamp_local': '2023-09-15T12:53:28', 'url': 'https://api.quant-aq.com/v1/devices/MOD-00480/data/62315101'}

# %% [markdown]
# ## Download an event window for all devices
#
# Next, we download data for the event window (Nov 7–10, 2024) for all devices visible to the API key. We store the results as raw files for later integration.

# %%
# import libraries
from pathlib import Path
import pandas as pd
from quantaq.utils import to_dataframe

# ---- Paths (match the PurpleAir acquisition notebook style) ----
BASE_DIR = Path(".")
DATA_DIR = BASE_DIR / "data"
RAW_DIR = DATA_DIR / "raw" / "quantaq"
RAW_DIR.mkdir(parents=True, exist_ok=True)

# ---- Event window ----
EVENT_START = "2024-11-07"
EVENT_END   = "2024-11-10"

# ---- Device inventory (metadata) ----
devices = client.devices.list()

devices_df = pd.DataFrame(devices)
devices_meta_path = RAW_DIR / "SouthBronxQuantAQDevices.parquet"
devices_df.to_parquet(devices_meta_path, index=False)
print(f"Saved device metadata to {devices_meta_path}")

# ---- Download measurements ----
rows = []
for device in devices:
    sn = device.get("sn")
    desc = device.get("description", "")
    if not sn:
        continue

    print(f"Downloading: {sn} - {desc}")

    # For each device, query the API for each day in the event window
    for each in pd.date_range(start=EVENT_START, end=EVENT_END, freq="D"):
        day_df = to_dataframe(client.data.bydate(sn=sn, date=str(each.date())))
        if day_df is not None and len(day_df) > 0:
            # Keep identifiers for integration later
            day_df["sn"] = sn
            day_df["description"] = desc
            rows.append(day_df)

if len(rows) == 0:
    raise RuntimeError("No QuantAQ data returned for the requested event window.")

df = pd.concat(rows, ignore_index=True)

# Drop some fields that are not useful for this lesson (keep errors='ignore' for robustness)
fields_to_drop = [
    "met.rh", "met.temp", "met.wd", "met.ws", "met.ws_scalar",
    "model.gas.co", "model.gas.no", "model.gas.no2", "model.gas.o3",
    "model.pm.pm1", "model.pm.pm10", "model.pm.pm25",
]
df = df.drop(columns=fields_to_drop, errors="ignore")

# ---- Save outputs ----
out_parquet = RAW_DIR / "SouthBronx_QuantAQ_2024_11_07_to_11_10.parquet"
df.to_parquet(out_parquet, index=False)
print(f"Saved merged QuantAQ data to {out_parquet} with shape {df.shape}")

# Optional CSV for quick inspection / compatibility
out_csv = RAW_DIR / "SouthBronx_QuantAQ_2024_11_07_to_11_10.csv"
df.to_csv(out_csv, index=False)
print(f"Saved CSV copy to {out_csv}")
# Out:
# Saved device metadata to data\raw\quantaq\SouthBronxQuantAQDevices.parquet
# Downloading: MOD-PM-01144 - MOD-PM-01144 - La Finca del Sur (110 E 138th St)
# Downloading: MOD-PM-01145 - MOD-PM-01145 - St Ann's Episcopal Church
# Downloading: MOD-PM-01146 - MOD-PM-01146 - The Family School
# Downloading: MOD-PM-01147 - MOD-PM-01147 - 335 E 140th St
# Downloading: MOD-PM-01148 - MOD-PM-01148 - Ethical Culture Fieldston School
# Downloading: MOD-PM-01149 - MOD-PM-01149, Association for Energy Affordability
# Downloading: MOD-PM-01150 - MOD-PM-01150 - Brook Park
# Downloading: MOD-00478 - MOD-00478, SBU Office
# Downloading: MOD-00479 - MOD-00479 - Bruckner Garden
# Downloading: MOD-00480 - MOD-00480 - Harlem River Yards Waste Transfer Station
# Downloading: MOD-00481 - MOD-00481 - South Bronx Unite Office (Outside)
# Downloading: MOD-00482 - MOD-00482 - Governors Island (Liberty Vista)
# Downloading: MOD-PM-01151 - MOD-PM-01151 - 408 E 136th St
# Downloading: MOD-PM-01152 - MOD-PM-01152 - MSHS 223 (423 Willis Ave)
# Downloading: MOD-PM-01153 - MOD-PM-01153 - Latino Pastoral Action Center
# Downloading: MOD-PM-01154 - MOD-PM-01154 - El Coqui Garden (414 E 163rd St)
# Downloading: MOD-PM-01155 - MOD-PM-01155 Revel Site (799 E 140th St)
# Downloading: MOD-PM-01156 - MOD-PM-01156 Rainbow Garden
# Downloading: MOD-PM-01157 - MOD-PM-01157 - P.S 126 Dr Marjorie H. Dunbar School
# Downloading: MOD-PM-01158 - MOD-PM-01158 - MSHS 223 (368 E 144th St)
# Downloading: MOD-PM-01159 - MOD-PM-01159 - 33 Tinton Ave
# Downloading: MOD-PM-01160 - MOD-PM-01160 - MS 302: Ground Level
# Downloading: MOD-PM-01161 - MOD-PM-01161 X285 The Highbridge Green School
# Downloading: MOD-PM-01162 - MOD-PM-01162 870 Southern Boulevard (SEBCO)
# Downloading: MOD-PM-01163 - MOD-PM-01163 - NYCSBUS Zerega School Bus Depot (1101 Zerega Ave)
# Downloading: MOD-PM-01315 - MOD-PM-01315 - Bronx Collegiate Academy
# Downloading: MOD-PM-01316 - SBU Test Monitor 4 - PM
# Downloading: MOD-PM-01317 - MOD-PM-01317 - Maria Sola Garden
# Downloading: MOD-PM-01318 - MOD-PM-01318, 1212 Seneca Ave (SEBCO)
# Downloading: MOD-PM-01319 - SBU
# Downloading: MOD-PM-01320 - MOD-PM-01320 P.S.170
# Downloading: MOD-PM-01321 - MOD-PM-01321 817 Faile St (SEBCO)
# Downloading: MOD-PM-01322 - MOD-PM-01322, 852 E 165th St (SEBCO)
# Downloading: MOD-PM-01323 - MOD-PM-01323 X114 Lewis Llorens Torres Academy
# Downloading: MOD-PM-01324 - MOD-PM-01324 - 567 Southern Boulevard (SEBCO)
# Downloading: MOD-PM-01325 - MOD-PM-01325, 852 E 163rd St (SEBCO)
# Downloading: MOD-PM-01326 - MOD-PM-01326 - 580 Courtlandt Ave (SEBCO)
# Downloading: MOD-PM-01327 - MOD-PM-01327 - Test Monitor 9 - PM
# Downloading: MOD-PM-01328 - MOD-PM-01328 - 665 Casanova St (SEBCO)
# Downloading: MOD-PM-01329 - MOD-PM-01329 - Test Monitor 10 - PM
# Downloading: MOD-PM-01330 - MOD-PM-01330- P.S. 070 Max Schoenfeld School
# Downloading: MOD-PM-01331 - MOD-PM-01331 - 575 E 161st St (SEBCO)
# Downloading: MOD-PM-01333 - MOD-PM-01333 - SEBCO 390 Jackson Ave
# Downloading: MOD-PM-01334 - MOD-PM-01334 - 479 Courtlandt Ave (SEBCO)
# Downloading: MOD-PM-01332 - MOD-PM-01332 994 Intervale Ave (SEBCO)
# Downloading: MOD-00693 - MOD-00693 - Cross Bronx Expressway
# Downloading: MOD-00694 - MOD-00694
# Downloading: MOD-00695 - MOD-00695 - 1150 Garrison Ave (SEBCO)
# Downloading: MOD-00696 - MOD-00696 Randall's Island/Sunken Meadow Restroom
# Downloading: MOD-00697 - MOD-00697 - Hostos Community College
# Downloading: MOD-00778 - MOD-00778 Residential Apt. - 700 E 134th St
# Downloading: MOD-00779 - MOD-00779 - MS 302 (DEC Monitor) (Roof)
# Downloading: MOD-00780 - MOD-00780 MS 004 (Crotona Park West) GAS
# Downloading: MOD-00781 - MOD-00781 - SBU big conf. rm. 127 Lincoln Ave.
# Downloading: MOD-00782 - MOD-00782 X320 Samara Community School
# Downloading: MOD-PM-01459 - MOD-PM-01459
# Downloading: MOD-PM-01460 - MOD-PM-01460, P.S.11 The Highbridge School
# Downloading: MOD-PM-01461 - MOD-PM-01461
# Downloading: MOD-PM-01462 - MOD-PM-01462 - The Shakespear School (P.S. 199)
# Downloading: MOD-PM-01463 - MOD-PM-01463 - Bronx Leadership Academy HS (X876)
# Downloading: MOD-PM-01464 - MOD-PM-01464 - (X460) Bronx School for Law, Government and Justice
# Downloading: MOD-PM-01465 - MOD-PM-01465 P.S. X088 Silverstein Little Sparrow School
# Downloading: MOD-PM-01466 - MOD-PM-01466 - School X147 School of leadership development
# Downloading: MOD-PM-01467 - SBU
# Downloading: MOD-PM-01468 - SBU
# C:\Users\kyttm\AppData\Local\Temp\ipykernel_38184\1999844940.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(rows, ignore_index=True)
# Saved merged QuantAQ data to data\raw\quantaq\SouthBronx_QuantAQ_2024_11_07_to_11_10.parquet with shape (232518, 20)
# Saved CSV copy to data\raw\quantaq\SouthBronx_QuantAQ_2024_11_07_to_11_10.csv
